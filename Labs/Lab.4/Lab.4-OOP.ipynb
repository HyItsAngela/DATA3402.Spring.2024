# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    def __init__(self, max_value):
        self.value=0
        self.max_value=max_value
        
    def increment(self, inc_):
        for _ in range(inc_range):
            if self.value<self.max_value:
                self.value+=1
                print(f"Counter incremented to {self.value}")
            else:
                print(f"Error 1: Attempt to increment is beyond maximum value: {self.max_value}. Reset counter.")
                self.value=0
                print("Counter reset to 0")
                break
        
max_value=10
inc_range=15
counter=counter(max_value)
counter.increment(inc_range)
# Out:
# Counter incremented to 1
# Counter incremented to 2
# Counter incremented to 3
# Counter incremented to 4
# Counter incremented to 5
# Counter incremented to 6
# Counter incremented to 7
# Counter incremented to 8
# Counter incremented to 9
# Counter incremented to 10
# Error 1: Attempt to increment is beyond maximum value: 10. Reset counter.
# Counter reset to 0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
#(__) considered private and are meant to be only called by the class.

class counter:
    def __init__(self, max_value):
        self.__value=0
        self.__max_value=max_value
        
    def increment(self, inc_):
        for _ in range(inc_range):
            if self.__value<self.__max_value:
                self.__value+=1
                print(f"Counter incremented to {self.__value}")
            else:
                print(f"Error 1: Attempt to increment is beyond maximum value: {self.__max_value}. Reset counter.")
                self.__value=0
                print("Counter reset to 0")
                break
                
    def get_value(self):
        return self.__value
    
    def get_max_value(self):
        return self.__max_value
    
    def is_count_max(self):
        return self.__value==self.__max_value
        
max_value=10
inc_range=15
counter=counter(max_value)
counter.increment(inc_range)

print(f"Current value: {counter.get_value()}")
print(f"Maximum value: {counter.get_max_value()}")
print(f"Is increment at maximum value? {counter.is_count_max()}")
# Out:
# Counter incremented to 1
# Counter incremented to 2
# Counter incremented to 3
# Counter incremented to 4
# Counter incremented to 5
# Counter incremented to 6
# Counter incremented to 7
# Counter incremented to 8
# Counter incremented to 9
# Counter incremented to 10
# Error 1: Attempt to increment is beyond maximum value: 10. Reset counter.
# Counter reset to 0
# Current value: 0
# Maximum value: 10
# Is increment at maximum value? False

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class rect:
    def __init__(self,l,w,x,y):
        self.__l=l
        self.__w=w
        self.__x=x
        self.__y=y
       
    #accessors; retrieves values of the data members
    def get_l(self):
        return self.__l
    
    def get_w(self):
        return self.__w
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
    
    #setters
    def set_l(self,l):
        self.__l=l
        
    def set_w(self,w):
        self.__w=w
        
    def set_x(self,x):
        self.__x=x
        
    def set_y(self,y):
        self.__y=y
        
    #compute area and perimeter functions
    def area(self):
        return self.__l * self.__w
    
    def perimeter(self):
        return 2 * (self.__l + self.__w)
    
rectangle=rect(l=5, w=5, x=2, y=4)

print(f"Length: {rectangle.get_l()}")
print(f"Width: {rectangle.get_w()}")
print(f"X-coordinate: {rectangle.get_x()}")
print(f"Y-coordinate: {rectangle.get_y()}")

print(f"Area: {rectangle.area()}")
print(f"Perimeter: {rectangle.perimeter()}")
# Out:
# Length: 5
# Width: 5
# X-coordinate: 2
# Y-coordinate: 4
# Area: 25
# Perimeter: 20

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class circle:
    def __init__(self,radi,x,y):
        self.__radi=radi
        self.__x=x
        self.__y=y
        
    #accessors
    def get_radi(self):
        return self.__radi
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
    
    #setters
    def set_radi(self,radi):
        self.__radi=radi
        
    def set_x(self,x):
        self.__x=x
        
    def set_y(self,y):
        self.__y=y
        
    #compute area and circumference functions
    def area(self):
        return 3.14 * (self.__radi ** 2)
    
    def circum(self):
        return 2 * 3.14 * self.__radi
    
circle=circle(radi=6,x=8,y=3)

print(f"Radius: {circle.get_radi()}")
print(f"X-coordinate: {circle.get_x()}")
print(f"Y-coordinate: {circle.get_y()}")

print(f"Area: {circle.area()}")
print(f"Circumference: {circle.circum()}")
# Out:
# Radius: 6
# X-coordinate: 8
# Y-coordinate: 3
# Area: 113.04
# Circumference: 37.68

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class shape:
    def __init__(self,x,y):
        self.__x=x
        self.__y=y
        
    #virtual method
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
        
class rect(shape):
    def __init__(self,l,w,x,y):
        super().__init__(x,y)
        self.__l=l
        self.__w=w
        
    #accessors; retrieves values of the data members
    def get_l(self):
        return self.__l
    
    def get_w(self):
        return self.__w
    
    #setters
    def set_l(self,l):
        self.__l=l
        
    def set_w(self,w):
        self.__w=w
        
    #compute area and perimeter functions
    def area(self):
        return self.__l * self.__w
    
    def perimeter(self):
        return 2 * (self.__l + self.__w)
    
class circle(shape):
    def __init__(self,radi,x,y):
        super().__init__(x,y)
        self.__radi=radi
        
    #accessors
    def get_radi(self):
        return self.__radi
    
    #setters
    def set_radi(self,radi):
        self.__radi=radi
        
    #compute area and circumference functions
    def area(self):
        return 3.14 * (self.__radi ** 2)
    
    def perimeter(self):
        return 2 * 3.14 * self.__radi
    
rectangle=rect(l=5, w=5, x=2, y=4)
circle=circle(radi=6,x=8,y=3)

print("Rectangle:")
print(f"Area: {rectangle.area()}")
print(f"Perimeter: {rectangle.perimeter()}")

print("\nCircle:")
print(f"Area: {circle.area()}")
print(f"Circumference: {circle.perimeter()}")
# Out:
# Rectangle:
# Area: 25
# Perimeter: 20
#
# Circle:
# Area: 113.04
# Circumference: 37.68

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class tri(shape):
    def __init__(self,a,b,c,x,y):
        super().__init__(x,y)
        self.__a=a
        self.__b=b
        self.__c=c
        
    #accessors
    def get_a(self):
        return self.__a
    
    def get_b(self):
        return self.__b
    
    def get_c(self):
        return self.__c
    
    #setters
    def set_a(self,a):
        self.__a=a
        
    def set_b(self,b):
        self.__b=b
        
    def set_c(self,c):
        self.__c=c
        
    #compute area and perimenter functions
    def area(self):
        #Heron's formula
        s=(self.__a + self.__b + self.__c)/2 #semi-perimeter
        return (s * (s-self.__a) * (s-self.__b) * (s-self.__c)) ** 0.5
    
    def perimeter(self):
        return self.__a + self.__b + self.__c
    
triangle = tri(a=2, b=4, c=6, x=1, y=1)

print("Triangle:")
print(f"Area: {triangle.area()}")
print(f"Perimeter: {triangle.perimeter()}")
# Out:
# Triangle:
# Area: 0.0
# Perimeter: 12

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
import math

class shape:
    def __init__(self,x,y):
        self.__x=x
        self.__y=y
        
    #virtual method
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
        
    #accessors
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    #setters
    def set_x(self, x):
        self.__x=x

    def set_y(self, y):
        self.__y=y
        
    #new code, 16 perimeter of shape
    def perimeter_points(self,num_points=16):
        raise NotImplementedError
        
class rect(shape):
    def __init__(self,l,w,x,y):
        super().__init__(x,y)
        self.__l=l
        self.__w=w
        
    #accessors; retrieves values of the data members
    def get_l(self):
        return self.__l
    
    def get_w(self):
        return self.__w
    
    #setters
    def set_l(self,l):
        self.__l=l
        
    def set_w(self,w):
        self.__w=w
        
    #compute area and perimeter functions
    def area(self):
        return self.__l * self.__w
    
    def perimeter(self):
        return 2 * (self.__l + self.__w)
    
    #new code, 16 pairs on perimeter of shape
    def perimeter_points(self,num_points=16):
        x=self.get_x()
        y=self.get_y()
        l=self.get_l()
        w=self.get_w()
        
        points=[((x+l,y+i), #horizontal sides (iterate along length)
               (x+i,y+w)) #vertical sides (iterate along width)
               for i in range(num_points)] 
        return points
    
class circle(shape):
    def __init__(self,radi,x,y):
        super().__init__(x,y)
        self.__radi=radi
        
    #accessors
    def get_radi(self):
        return self.__radi
    
    #setters
    def set_radi(self,radi):
        self.__radi=radi
        
    #compute area and circumference functions
    def area(self):
        return 3.14 * (self.__radi ** 2)
    
    def perimeter(self):
        return 2 * 3.14 * self.__radi
    
    #new code, 16 pairs on perimeter of shape
    def perimeter_points(self,num_points=16):
        x=self.get_x()
        y=self.get_y()
        radi=self.get_radi()
        
        points=[(x+radi*math.cos(2*math.pi*i/num_points),
                y+radi*math.sin(2*math.pi*i/num_points))
               for i in range(num_points)]
        return points
    
class tri(shape):
    def __init__(self,a,b,c,x,y):
        super().__init__(x,y)
        self.__a=a
        self.__b=b
        self.__c=c
        
    #accessors
    def get_a(self):
        return self.__a
    
    def get_b(self):
        return self.__b
    
    def get_c(self):
        return self.__c
    
    #setters
    def set_a(self,a):
        self.__a=a
        
    def set_b(self,b):
        self.__b=b
        
    def set_c(self,c):
        self.__c=c
        
    #compute area and perimenter functions
    def area(self):
        #Heron's formula
        s=(self.__a + self.__b + self.__c)/2 #semi-perimeter
        return (s * (s-self.__a) * (s-self.__b) * (s-self.__c)) ** 0.5
    
    def perimeter(self):
        return self.__a + self.__b + self.__c
    
    #new code, 16 pairs on perimeter of shape
    def perimeter_points(self,num_points=16):
        x=self.get_x()
        y=self.get_y()
        a=self.get_a()
        
        points=[(x+a*math.cos(2*math.pi*i/num_points),
                y+a*math.sin(2*math.pi*i/num_points))
               for i in range(num_points)]
        return points
    
rectangle=rect(l=5, w=5, x=2, y=4)
circle=circle(radi=6,x=8,y=3)
triangle = tri(a=2, b=4, c=6, x=1, y=1)
    
print("Rectangle Perimeter Points:")
print(rectangle.perimeter_points())

print("\nCircle Perimeter Points:")
print(circle.perimeter_points())

print("\nTriangle Perimeter Points:")
print(triangle.perimeter_points())
# Out:
# Rectangle Perimeter Points:
# [((7, 4), (2, 9)), ((7, 5), (3, 9)), ((7, 6), (4, 9)), ((7, 7), (5, 9)), ((7, 8), (6, 9)), ((7, 9), (7, 9)), ((7, 10), (8, 9)), ((7, 11), (9, 9)), ((7, 12), (10, 9)), ((7, 13), (11, 9)), ((7, 14), (12, 9)), ((7, 15), (13, 9)), ((7, 16), (14, 9)), ((7, 17), (15, 9)), ((7, 18), (16, 9)), ((7, 19), (17, 9))]
#
# Circle Perimeter Points:
# [(14.0, 3.0), (13.54327719506772, 5.296100594190539), (12.242640687119286, 7.242640687119285), (10.29610059419054, 8.54327719506772), (8.0, 9.0), (5.703899405809461, 8.54327719506772), (3.7573593128807152, 7.242640687119286), (2.45672280493228, 5.2961005941905395), (2.0, 3.000000000000001), (2.456722804932279, 0.7038994058094619), (3.7573593128807143, -1.2426406871192848), (5.703899405809458, -2.543277195067719), (7.999999999999999, -3.0), (10.29610059419054, -2.54327719506772), (12.242640687119284, -1.2426406871192857), (13.54327719506772, 0.7038994058094579)]
#
# Triangle Perimeter Points:
# ...

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
import math

class shape:
    def __init__(self,x,y):
        self.__x=x
        self.__y=y
        
    #virtual method
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
        
    #accessors
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    #setters
    def set_x(self, x):
        self.__x=x

    def set_y(self, y):
        self.__y=y
        
    def perimeter_points(self,num_points=16):
        raise NotImplementedError
        
    #new code, test if point is inside a object
    def in_point(self,test_x,test_y):
        raise NotImplementedError
        
class rect(shape):
    def __init__(self,l,w,x,y):
        super().__init__(x,y)
        self.__l=l
        self.__w=w
        
    #accessors; retrieves values of the data members
    def get_l(self):
        return self.__l
    
    def get_w(self):
        return self.__w
    
    #setters
    def set_l(self,l):
        self.__l=l
        
    def set_w(self,w):
        self.__w=w
        
    #compute area and perimeter functions
    def area(self):
        return self.__l * self.__w
    
    def perimeter(self):
        return 2 * (self.__l + self.__w)
    
    def perimeter_points(self,num_points=16):
        x=self.get_x()
        y=self.get_y()
        l=self.get_l()
        w=self.get_w()
        
        points=[((x+l,y+i), #horizontal sides (iterate along length)
               (x+i,y+w)) #vertical sides (iterate along width)
               for i in range(num_points)] 
        return points
    
    #new code, test if point is inside a object
    def in_point(self,test_x,test_y):
        x=self.get_x()
        y=self.get_y()
        l=self.get_l()
        w=self.get_w()
        return x<=test_x<=x+l and y<=test_y<=y+w
    
class circle(shape):
    def __init__(self,radi,x,y):
        super().__init__(x,y)
        self.__radi=radi
        
    #accessors
    def get_radi(self):
        return self.__radi
    
    #setters
    def set_radi(self,radi):
        self.__radi=radi
        
    #compute area and circumference functions
    def area(self):
        return 3.14 * (self.__radi ** 2)
    
    def perimeter(self):
        return 2 * 3.14 * self.__radi
    
    def perimeter_points(self,num_points=16):
        x=self.get_x()
        y=self.get_y()
        radi=self.get_radi()
        
        points=[(x+radi*math.cos(2*math.pi*i/num_points),
                y+radi*math.sin(2*math.pi*i/num_points))
               for i in range(num_points)]
        return points
    
    #new code, test if point is inside a object
    def in_point(self,test_x,test_y):
        x=self.get_x()
        y=self.get_y()
        radi=self.get_radi()
        return (test_x-x)**2+(test_y-y)**2<=radi**2
    
class tri(shape):
    def __init__(self,a,b,c,x,y):
        super().__init__(x,y)
        self.__a=a
        self.__b=b
        self.__c=c
        
    #accessors
    def get_a(self):
        return self.__a
    
    def get_b(self):
        return self.__b
    
    def get_c(self):
        return self.__c
    
    #setters
    def set_a(self,a):
        self.__a=a
        
    def set_b(self,b):
        self.__b=b
        
    def set_c(self,c):
        self.__c=c
        
    #compute area and perimenter functions
    def area(self):
        #Heron's formula
        s=(self.__a + self.__b + self.__c)/2 #semi-perimeter
        return (s * (s-self.__a) * (s-self.__b) * (s-self.__c)) ** 0.5
    
    def perimeter(self):
        return self.__a + self.__b + self.__c
    
    def perimeter_points(self,num_points=16):
        x=self.get_x()
        y=self.get_y()
        a=self.get_a()
        
        points=[(x+a*math.cos(2*math.pi*i/num_points),
                y+a*math.sin(2*math.pi*i/num_points))
               for i in range(num_points)]
        return points
    
    #new code, test if point is inside a object
    def in_point(self,test_x,test_y):
        x=self.get_x()
        y=self.get_y()
        a=self.get_a()
        return "?"
    
rectangle=rect(l=5, w=5, x=2, y=4)
circle=circle(radi=6,x=8,y=3)

testcd_rect=(1,2)
testcd_circle=(4,4)


print(f"Rectangle test point: {testcd_rect}")
print(f"Point inside rectangle: {rectangle.in_point(*testcd_rect)}")
print(f"\nCircle test point: {testcd_circle}")
print(f"Point inside circle: {circle.in_point(*testcd_circle)}")
# Out:
# Rectangle test point: (1, 2)
# Point inside rectangle: False
#
# Circle test point: (4, 4)
# Point inside circle: True

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
import math

class shape:
    def __init__(self,x,y):
        self.__x=x
        self.__y=y
        
    #virtual method
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
        
    #accessors
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    #setters
    def set_x(self, x):
        self.__x=x

    def set_y(self, y):
        self.__y=y
        
    def perimeter_points(self,num_points=16):
        raise NotImplementedError
        
    def in_point(self,test_x,test_y):
        raise NotImplementedError
        
    #new code, test if shape intersects with another object
    def intersect(self,obj):
        raise NotImplementedError
        
class rect(shape):
    def __init__(self,l,w,x,y):
        super().__init__(x,y)
        self.__l=l
        self.__w=w
        
    #accessors; retrieves values of the data members
    def get_l(self):
        return self.__l
    
    def get_w(self):
        return self.__w
    
    #setters
    def set_l(self,l):
        self.__l=l
        
    def set_w(self,w):
        self.__w=w
        
    #compute area and perimeter functions
    def area(self):
        return self.__l * self.__w
    
    def perimeter(self):
        return 2 * (self.__l + self.__w)
    
    def perimeter_points(self,num_points=16):
        x=self.get_x()
        y=self.get_y()
        l=self.get_l()
        w=self.get_w()
        
        points=[((x+l,y+i), #horizontal sides (iterate along length)
               (x+i,y+w)) #vertical sides (iterate along width)
               for i in range(num_points)] 
        return points
    
    def in_point(self,test_x,test_y):
        x=self.get_x()
        y=self.get_y()
        l=self.get_l()
        w=self.get_w()
        return x<=test_x<=x+l and y<=test_y<=y+w
    
    #new code, test if shape intersects with another object
    def intersect(self,obj):
        x1,y1=self.get_x(),self.get_y()
        x2,y2=obj.get_x(),self.get_y()
        l1,w1=self.get_l(),self.get_w()
        l2,w2=obj.get_l(),obj.get_w()
        return x1+w1<=x2 or x2+w2<=x1 or y2+l2<=y2 or y1+l1<=y2
    
class circle(shape):
    def __init__(self,radi,x,y):
        super().__init__(x,y)
        self.__radi=radi
        
    #accessors
    def get_radi(self):
        return self.__radi
    
    #setters
    def set_radi(self,radi):
        self.__radi=radi
        
    #compute area and circumference functions
    def area(self):
        return 3.14 * (self.__radi ** 2)
    
    def perimeter(self):
        return 2 * 3.14 * self.__radi
    
    def perimeter_points(self,num_points=16):
        x=self.get_x()
        y=self.get_y()
        radi=self.get_radi()
        
        points=[(x+radi*math.cos(2*math.pi*i/num_points),
                y+radi*math.sin(2*math.pi*i/num_points))
               for i in range(num_points)]
        return points
    
    def in_point(self,test_x,test_y):
        x=self.get_x()
        y=self.get_y()
        radi=self.get_radi()
        return (test_x-x)**2+(test_y-y)**2<=radi**2
    
    #new code, test if shape intersects with another object
    def intersect(self,obj):
        #only works when comparing circle with another circle
        center_diff=math.sqrt((self.get_x()-obj.get_x())**2 + #distance formula: check distance between center of both objects
                             (self.get_y()-obj.get_y())**2)
        return center_diff<(self.get_radi()+obj.get_radi()) #if the distance between the centers are less than the sum of radii
    
class tri(shape):
    def __init__(self,a,b,c,x,y):
        super().__init__(x,y)
        self.__a=a
        self.__b=b
        self.__c=c
        
    #accessors
    def get_a(self):
        return self.__a
    
    def get_b(self):
        return self.__b
    
    def get_c(self):
        return self.__c
    
    #setters
    def set_a(self,a):
        self.__a=a
        
    def set_b(self,b):
        self.__b=b
        
    def set_c(self,c):
        self.__c=c
        
    #compute area and perimenter functions
    def area(self):
        #Heron's formula
        s=(self.__a + self.__b + self.__c)/2 #semi-perimeter
        return (s * (s-self.__a) * (s-self.__b) * (s-self.__c)) ** 0.5
    
    def perimeter(self):
        return self.__a + self.__b + self.__c
    
    def perimeter_points(self,num_points=16):
        x=self.get_x()
        y=self.get_y()
        a=self.get_a()
        
        points=[(x+a*math.cos(2*math.pi*i/num_points),
                y+a*math.sin(2*math.pi*i/num_points))
               for i in range(num_points)]
        return points
    
    def in_point(self,test_x,test_y):
        x=self.get_x()
        y=self.get_y()
        a=self.get_a()
        return "?"
    
    #new code, test if shape intersects with another object
    def intersect(self,obj):
        return "?"
    
rectangle=rect(l=5, w=5, x=2, y=4)
circle1=circle(radi=6,x=8,y=3)
circle2=circle(radi=4,x=2,y=3)

print(circle1.intersect(circle2))
# Out:
# True

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
from paint import Canvas,shape,rect,circle,tri,CompoundShape
circle1=circle(4,5,20)
rectangle=rect(2,2,13,19)
canvas1=Canvas(50,40)
compound_shape=CompoundShape(shapes=[circle1,rectangle])
canvas1.paint(compound_shape)
canvas1.display()
# Out:
#
#                   * **
#                  *    *
#                 *      *
#                 *
#                         *
#                 *      *
#                  *    *
#                   *  *
#                     *
#
#
#
#                    ***
#                    * *
#                    **

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:
    def __init__(self):
        self.shapes=dict()
        self.shape_names=list()
        
    def add_shape(self,shape):
        if shape.name == "":
            shape.name = self.assign_name()
        
        self.shapes[shape.name]=shape
        self.shape_names.append(shape.name)

    def update(self, canvas):
        canvas.clear_canvas()
        self.paint(canvas)
        
    def paint(self,canvas):
        for shape_name in self.shape_names:
            self.shapes[shape_name].paint(canvas)
            
    def assign_name(self):
        name_base="shape"
        name = name_base+"_0"
        
        i=1
        while name in self.shapes:
            name = name_base+"_"+str(i)
            
        return name
    
canvas=Canvas(50,40)
rd=RasterDrawing()

rd.add_shape(rect(5,5,2,2,"rectangle"))
rd.add_shape(rect(5,5,2,"circle"))


#inital raster drawing
rd.paint(canvas)
canvas.display()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_117/756673450.py in <module>
#      37
#      38 #inital raster drawing
# ---> 39 rd.paint(canvas)
#      40 canvas.display()
#
# /tmp/ipykernel_117/756673450.py in paint(self, canvas)
#      17     def paint(self,canvas):
#      18         for shape_name in self.shape_names:
# ---> 19             self.shapes[shape_name].paint(canvas)
#      20
#      21     def assign_name(self):
#
# ~/DATA3402.Spring.2024/Labs/Lab.4/paint.py in paint(self, canvas)
#     140     #draw shape onto canvas
#     141     def paint(self, canvas):
# --> 142         canvas.v_line(self.get_x(), self.get_y(), self.get_w())
#     143         canvas.v_line(self.get_x(), self.get_y() + self.get_l(), self.get_w())
#     144         canvas.h_line(self.get_x(), self.get_y(), self.get_l())
#
# ...

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
    def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
class RasterDrawing:
    def __init__(self):
        self.shapes=dict()
        self.shape_names=list()
        
    def add_shape(self,shape):
        if shape.name == "":
            shape.name = self.assign_name()
        
        self.shapes[shape.name]=shape
        self.shape_names.append(shape.name)

    def update(self, canvas):
        canvas.clear_canvas()
        self.paint(canvas)
        
    def paint(self,canvas):
        for shape_name in self.shape_names:
            self.shapes[shape_name].paint(canvas)
            
    def assign_name(self):
        name_base="shape"
        name = name_base+"_0"
        
        i=1
        while name in self.shapes:
            name = name_base+"_"+str(i)
            
        return name


    def save(self, filename):
        with open(filename, 'w') as file:
            for shape_name in self.shape_names:
                shape_repr = repr(self.shapes[shape_name])
                file.write(f"{shape_repr}\n")

    def load(self, filename):
        with open(filename, 'r') as file:
            lines = file.readlines()
            for line in lines:
                shape = eval(line.strip())
                self.add_shape(shape)
    
    
    
    
    
rd.save("drawing.txt")
new_rd=RasterDrawing()
new_rd.load("drawing.txt")
new_rd.paint(canvas)
canvas.display
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_117/674751085.py in <module>
#      47
#      48
# ---> 49 rd.save("drawing.txt")
#      50 new_rd=RasterDrawing()
#      51 new_rd.load("drawing.txt")
#
# AttributeError: 'RasterDrawing' object has no attribute 'save'
